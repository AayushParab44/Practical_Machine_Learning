# %% [markdown]
# ![image.png](attachment:6de60910-6634-416a-99c7-95f0d112dd5e.png)![image.png](attachment:1467880e-2f78-4a3c-94a6-add55540f33f.png)

# %% [markdown]
# tanh is used in the hidden layers

# %% [markdown]
# max value of derivative of tanh function is 1.

# %% [markdown]
# tanh is slower because of exponential function

# %% [markdown]
# ReLU- Rectified Linear Unit

# %% [markdown]
# ![image.png](attachment:eb3a5088-e4f9-421e-8469-d38549cb9de9.png)![image.png](attachment:b1ff64bf-cca2-4eef-a687-85ec02e5df3a.png)

# %% [markdown]
# To check normal distribution-
# - Anderson Darling test
#
# - 99.73% values fall between 3 std dev of mean.
# - 68% values fall between 1 std dev of mean.

# %% [markdown]
# Loss Functions-

# %% [markdown]
# MSE AND MAE

# %% [markdown]
# - mse calculations are very sensitive(not robust) to outliers(this is because of squaring the values).
# - mae does not have this problem

# %% [markdown]
# Huber Loss
# -delta - hyperparameter
# -if |yp-ya|<=delta # implies outliers do not have huge effect on our error.
# -then losses = (1/2)*sum((yb-ya)**2) #We use mse
#
#
# - else: losses = delta*|(yb-ya)|-(1/2)*delta**2 #We use mae #outliers
# - value of delta depends on our problem.

# %% [markdown]
# Log likelyhood
